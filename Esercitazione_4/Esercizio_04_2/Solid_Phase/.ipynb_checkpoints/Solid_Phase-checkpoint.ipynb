# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
import scipy.stats
# Out:
# /home/andrea/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
plt.rcParams.update({'font.size': 18})

# %%
data1 = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_4/Esercizio_04_2/Solid_Phase/nsl_simulator/NSL_SIMULATOR/OUTPUT/total_energy.dat", skiprows=1)

# %%
N=10                # Number of blocks
L=1000            # Number of steps in each block
x = np.arange(N)      # [0,1,2,...,N-1]

x*=L # Number of steps = block * (Number of steps in each block)
plt.errorbar(x,data1[:, 2],yerr=data1[:, -1])
plt.xlabel('#steps')
plt.ylabel('E*/N')
plt.title('Total (internal) energy per particle')
plt.grid(True)
plt.show()

# %%
data2 = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_4/Esercizio_04_2/Solid_Phase/nsl_simulator/NSL_SIMULATOR/OUTPUT/potential_energy.dat", skiprows=1)

# %%
plt.errorbar(x,data2[:, 2],yerr=data2[:, -1])
plt.xlabel('#steps')
plt.ylabel('U*/N')
plt.title('Potential energy per particle')
plt.grid(True)
plt.show()

# %%
data3 = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_4/Esercizio_04_2/Solid_Phase/nsl_simulator/NSL_SIMULATOR/OUTPUT/kinetic_energy.dat", skiprows=1)

# %%
plt.errorbar(x,data3[:, 2],yerr=data3[:, -1])
plt.xlabel('#steps')
plt.ylabel('K*/N')
plt.title('Kinteic energy per particle')
plt.grid(True)
plt.show()

# %%
data4 = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_4/Esercizio_04_2/Solid_Phase/nsl_simulator/NSL_SIMULATOR/OUTPUT/temperature.dat", skiprows=1)

# %%
plt.errorbar(x,data4[:, 2],yerr=data4[:, -1])
plt.xlabel('#steps')
plt.ylabel('T*')
plt.title('Temperature')
plt.grid(True)
plt.show()

# %%
data5 = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_4/Esercizio_04_2/Solid_Phase/nsl_simulator/NSL_SIMULATOR/OUTPUT/pressure.dat", skiprows=1)

# %%
plt.errorbar(x,data5[:, 2],yerr=data5[:, -1])
plt.xlabel('#steps')
plt.ylabel('P*')
plt.title('Pressure')
plt.grid(True)
plt.show()
