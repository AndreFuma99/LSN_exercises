# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
import scipy.stats

# %%
data1 = pd.read_csv("Es03_1C.csv", sep=',')

# %%
print(data1.head(8))
# Out:
#    CumulativeAverage  StatisticalUncertainty
# 0            19.9457                0.000000
# 1            18.2916                1.654050
# 2            16.6039                1.939170
# 3            16.3894                1.387870
# 4            16.0364                1.131520
# 5            16.1867                0.936022
# 6            15.9984                0.813184
# 7            16.0165                0.704471

# %%
M=10000              # Total number of throws
N=100                 # Number of blocks
L=int(M/N)            # Number of throws in each block, please use for M a multiple of N
x = np.arange(N)      # [0,1,2,...,N-1]

x*=L # Number of throws = block * (Number of throws in each block)
plt.errorbar(x,data1['CumulativeAverage'],yerr=data1['StatisticalUncertainty'])
plt.axhline(14.97)
plt.xlabel('#throws')
plt.ylabel('<C>')
plt.grid(True)
plt.show()

# %%
data2 = pd.read_csv("Es03_1P.csv", sep=',')

# %%
print(data2.head(8))
# Out:
#    CumulativeAverage  StatisticalUncertainty
# 0            3.95067                0.000000
# 1            4.98050                1.029830
# 2            5.51169                0.797295
# 3            5.07343                0.714077
# 4            5.26841                0.586479
# 5            5.31974                0.481602
# 6            5.36980                0.410095
# 7            5.40151                0.356566

# %%
plt.errorbar(x,data2['CumulativeAverage'],yerr=data2['StatisticalUncertainty'])
plt.axhline(5.46)
plt.xlabel('#throws')
plt.ylabel('<P>')
plt.grid(True)
plt.show()
