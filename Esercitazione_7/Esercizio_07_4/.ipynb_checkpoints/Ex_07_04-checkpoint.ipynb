# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
import scipy.stats
# Out:
# /home/andrea/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
U_S = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_7/Esercizio_07_4/nsl_simulator/NSL_SIMULATOR/OUTPUT/potential_energy_S.dat", skiprows=1)

# %%
dim=20
x = np.arange(dim)
x*=2000
plt.figure(figsize=(25, 4))
plt.errorbar(x,U_S[:, 2],yerr=U_S[:, -1])
plt.xlabel('#steps')
plt.ylabel('U/N')
plt.title('Solid phase - Potential energy per particle')
plt.grid(True)
plt.show()

# %%
P_S = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_7/Esercizio_07_4/nsl_simulator/NSL_SIMULATOR/OUTPUT/pressure_S.dat", skiprows=1)

# %%
plt.figure(figsize=(25, 4))
plt.errorbar(x,P_S[:, 2],yerr=P_S[:, -1])
plt.xlabel('#steps')
plt.ylabel('P')
plt.title('Solid phase - Pressure')
plt.grid(True)
plt.show()

# %%
g_S = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_7/Esercizio_07_4/nsl_simulator/NSL_SIMULATOR/OUTPUT/gofr_S.dat", skiprows=1)

# %%
dim=100
x = np.linspace(0.0115, 2.2951, dim)
plt.figure(figsize=(25, 4))
plt.errorbar(x,g_S[1900:, 1],yerr=g_S[1900:, -1])
plt.axvline(x=2.2, color='r', linestyle='--')
plt.xlabel('r')
plt.ylabel('g(r)')
plt.title('Solid phase - Radial distribution function')
plt.grid(True)
plt.show()

# %%
U_L = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_7/Esercizio_07_4/nsl_simulator/NSL_SIMULATOR/OUTPUT/potential_energy_L.dat", skiprows=1)

# %%
dim=20
x = np.arange(dim)
x*=2000
plt.figure(figsize=(25, 4))
plt.errorbar(x,U_L[:, 2],yerr=U_L[:, -1])
plt.xlabel('#steps')
plt.ylabel('U/N')
plt.title('Liquid phase - Potential energy per particle')
plt.grid(True)
plt.show()

# %%
P_L = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_7/Esercizio_07_4/nsl_simulator/NSL_SIMULATOR/OUTPUT/pressure_L.dat", skiprows=1)

# %%
plt.figure(figsize=(25, 4))
plt.errorbar(x,P_L[:, 2],yerr=P_L[:, -1])
plt.xlabel('#steps')
plt.ylabel('P')
plt.title('Liquid phase - Pressure')
plt.grid(True)
plt.show()

# %%
g_L = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_7/Esercizio_07_4/nsl_simulator/NSL_SIMULATOR/OUTPUT/gofr_L.dat", skiprows=1)

# %%
dim=100
x = np.linspace(0.0128, 2.5521, dim)
plt.figure(figsize=(25, 4))
plt.errorbar(x,g_L[1900:, 1],yerr=g_L[1900:, -1])
plt.axvline(x=2.5, color='r', linestyle='--')
plt.xlabel('r')
plt.ylabel('g(r)')
plt.title('Liquid phase - Radial distribution function')
plt.grid(True)
plt.show()

# %%
U_G = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_7/Esercizio_07_4/nsl_simulator/NSL_SIMULATOR/OUTPUT/potential_energy_G.dat", skiprows=1)

# %%
dim=20
x = np.arange(dim)
x*=2000
plt.figure(figsize=(25, 4))
plt.errorbar(x,U_G[:, 2],yerr=U_G[:, -1])
plt.xlabel('#steps')
plt.ylabel('U/N')
plt.title('Gas phase - Potential energy per particle')
plt.grid(True)
plt.show()

# %%
P_G = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_7/Esercizio_07_4/nsl_simulator/NSL_SIMULATOR/OUTPUT/pressure_G.dat", skiprows=1)

# %%
plt.figure(figsize=(25, 4))
plt.errorbar(x,P_G[:, 2],yerr=P_G[:, -1])
plt.xlabel('#steps')
plt.ylabel('P')
plt.title('Gas phase - Pressure')
plt.grid(True)
plt.show()

# %%
g_G = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_7/Esercizio_07_4/nsl_simulator/NSL_SIMULATOR/OUTPUT/gofr_G.dat", skiprows=1)

# %%
dim=100
x = np.linspace(0.0323, 6.4310, dim)
plt.figure(figsize=(25, 4))
plt.errorbar(x,g_G[1900:, 1],yerr=g_G[1900:, -1])
plt.axvline(x=5.0, color='r', linestyle='--')
plt.xlabel('r')
plt.ylabel('g(r)')
plt.title('Gas phase - Radial distribution function')
plt.grid(True)
plt.show()

# %%
data_s = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_7/Esercizio_07_4/nsl_simulator/NSL_SIMULATOR/OUTPUT/Tequilib_S.dat", skiprows=1)

# %%
dim=10000
x = np.arange(dim)
plt.figure(figsize=(25, 4))
plt.plot(x,data_s[:, 1])
plt.axhline(y=np.mean(data_s[:, 1]), color='r', linestyle='--')
plt.xlabel('#steps')
plt.ylabel('T')
plt.title('Solid phase equilibration')
plt.xlim(0, 1000)
plt.grid(True)
plt.show()

# %%
g_s = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_7/Esercizio_07_4/nsl_simulator/NSL_SIMULATOR/OUTPUT/gofr_NVE_S.dat", skiprows=1)

# %%
dim=100
x = np.linspace(0.0115, 2.2951, dim)
plt.figure(figsize=(25, 4))
plt.errorbar(x,g_S[1900:, 1],yerr=g_S[1900:, -1], label='MC NVT')
plt.errorbar(x,g_s[1900:, 1],yerr=g_s[1900:, -1], label='MD NVE')
plt.axvline(x=2.2, color='r', linestyle='--')
plt.xlabel('r')
plt.ylabel('g(r)')
plt.title('Solid phase - Radial distribution function')
plt.legend()
plt.grid(True)
plt.show()

# %%
data_l = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_7/Esercizio_07_4/nsl_simulator/NSL_SIMULATOR/OUTPUT/Tequilib_L.dat", skiprows=1)

# %%
dim=10000
x = np.arange(dim)
plt.figure(figsize=(25, 4))
plt.plot(x,data_l[:, 1])
plt.axhline(y=np.mean(data_l[:, 1]), color='r', linestyle='--')
plt.xlabel('#steps')
plt.ylabel('T')
plt.title('Liquid phase equilibration')
plt.xlim(0, 1000)
plt.grid(True)
plt.show()

# %%
g_l = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_7/Esercizio_07_4/nsl_simulator/NSL_SIMULATOR/OUTPUT/gofr_NVE_L.dat", skiprows=1)

# %%
dim=100
x = np.linspace(0.0128, 2.5521, dim)
plt.figure(figsize=(25, 4))
plt.errorbar(x,g_L[1900:, 1],yerr=g_L[1900:, -1], label='MC NVT')
plt.errorbar(x,g_l[1900:, 1],yerr=g_l[1900:, -1], label='MD NVE')
plt.axvline(x=2.5, color='r', linestyle='--')
plt.xlabel('r')
plt.ylabel('g(r)')
plt.title('Liquid phase - Radial distribution function')
plt.legend()
plt.grid(True)
plt.show()

# %%
data_g = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_7/Esercizio_07_4/nsl_simulator/NSL_SIMULATOR/OUTPUT/Tequib_G.dat", skiprows=1)

# %%
dim=10000
x = np.arange(dim)
plt.figure(figsize=(25, 4))
plt.plot(x,data_g[:, 1])
plt.axhline(y=np.mean(data_g[4000:, 1]), color='r', linestyle='--')
plt.xlabel('#steps')
plt.ylabel('T')
plt.title('Gas phase equilibration')
plt.grid(True)
plt.show()

# %%
g_g = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_7/Esercizio_07_4/nsl_simulator/NSL_SIMULATOR/OUTPUT/gofr_NVE_G.dat", skiprows=1)

# %%
dim=100
x = np.linspace(0.0323, 6.4310, dim)
plt.figure(figsize=(25, 4))
plt.errorbar(x,g_G[1900:, 1],yerr=g_G[1900:, -1], label='MC NVT')
plt.errorbar(x,g_g[1900:, 1],yerr=g_g[1900:, -1], label='MD NVE')
plt.axvline(x=5.0, color='r', linestyle='--')
plt.xlabel('r')
plt.ylabel('g(r)')
plt.title('Gas phase - Radial distribution function')
plt.legend()
plt.grid(True)
plt.show()
