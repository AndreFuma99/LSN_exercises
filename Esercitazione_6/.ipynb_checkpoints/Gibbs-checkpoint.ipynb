# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
import scipy.stats
# Out:
# /home/andrea/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_6/nsl_simulator/NSL_SIMULATOR/OUTPUT/total_energy.dat", skiprows=1)

# %%
N=10000               # Number of blocks
L=1            # Number of steps in each block
x = np.arange(N)      # [0,1,2,...,N-1]

x*=L # Number of steps = block * (Number of steps in each block)
plt.plot(x, data[:, 2])
plt.xlabel('#steps')
plt.ylabel('U/N')
plt.title('Equilibration')
plt.grid(True)
plt.show()

# %%
U = []
C = []
X = []
M = []

eU = []
eC = []
eX = []
eM = []

# %%
dataU = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_6/nsl_simulator/NSL_SIMULATOR/OUTPUT/total_energy.dat", skiprows=1)
dataC = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_6/nsl_simulator/NSL_SIMULATOR/OUTPUT/specific_heat.dat", skiprows=1)
dataX = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_6/nsl_simulator/NSL_SIMULATOR/OUTPUT/susceptibility.dat", skiprows=1)

# %%
U.append(dataU[-1, 2])
C.append(dataC[-1, 2])
X.append(dataX[-1, 2])

eU.append(dataU[-1, -1])
eC.append(dataC[-1, -1])
eX.append(dataX[-1, -1])

# %%
print(U)
print(C)
print(X)
# Out:
# [-0.47007, -0.516125, -0.582512, -0.665071, -0.761672, -0.870497, -0.971538]
# [0.196068, 0.23475, 0.287764, 0.349765, 0.411532, 0.421912, 0.217448]
# [1.37278, 1.77398, 2.49602, 3.97784, 7.30052, 19.2391, 76.6389]

# %%
print(eU)
print(eC)
print(eX)
# Out:
# [0.00788161, 0.000272669, 0.000348265, 0.000358296, 0.000369961, 0.00076436, 0.00100843]
# [0.00328493, 9.29483e-05, 0.000184545, 0.000298723, 0.000556555, 0.00238918, 0.00769313]
# [0.0230636, 0.00664479, 0.0151304, 0.0250685, 0.0764616, 0.322124, 1.00502]

# %%
x = [2.0, 1.75, 1.5, 1.25, 1.0, 0.75, 0.5]

plt.errorbar(x, U, yerr=eU)
plt.xlabel('T')
plt.ylabel('U/N')
plt.title('Ising 1D, internal energy')
plt.grid(True)
plt.show()

# %%
plt.errorbar(x, C, yerr=eC)
plt.xlabel('T')
plt.ylabel('C')
plt.title('Ising 1D, heat capacity')
plt.grid(True)
plt.show()

# %%
plt.errorbar(x, X, yerr=eX)
plt.xlabel('T')
plt.ylabel('$\chi$')
plt.title('Ising 1D, susceptibility')
plt.grid(True)
plt.show()

# %%
dataM = np.loadtxt("/home/andrea/Documenti/CorsoLSN/Esercitazione_6/nsl_simulator/NSL_SIMULATOR/OUTPUT/magnetization.dat", skiprows=1)
M.append(dataM[-1, 2])
eM.append(dataM[-1, -1])
print(M)
print(eM)
# Out:
# [0.0279751, 0.0368634, 0.05165, 0.0809493, 0.146709, 0.356813, 0.901758]
# [0.00129479, 0.0010042, 0.00126111, 0.00199553, 0.00411929, 0.00965284, 0.0121231]

# %%
plt.errorbar(x, M, yerr=eM)
plt.xlabel('T')
plt.ylabel('M')
plt.title('Ising 1D, magnetization with h=0.02')
plt.grid(True)
plt.show()
