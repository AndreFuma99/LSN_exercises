# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
import scipy.stats

# %%
data1 = pd.read_csv("Es02_1.csv", sep=',')

# %%
print(data1.head(8))
# Out:
#    CumulativeAverage  StatisticalUncertainty
# 0            1.06982                0.000000
# 1            1.05790                0.011923
# 2            1.03189                0.026906
# 3            1.02868                0.019296
# 4            1.01144                0.022813
# 5            1.01651                0.019303
# 6            1.01146                0.017078
# 7            1.00947                0.014922

# %%
M=10000              # Total number of throws
N=100                 # Number of blocks
L=int(M/N)            # Number of throws in each block, please use for M a multiple of N
x = np.arange(N)      # [0,1,2,...,N-1]

x*=L # Number of throws = block * (Number of throws in each block)
plt.errorbar(x,data1['CumulativeAverage'],yerr=data1['StatisticalUncertainty'])
plt.xlabel('#throws')
plt.ylabel('<I>')
plt.grid(True)
plt.show()

# %%
data2 = pd.read_csv("Es02_1a.csv", sep=',')

# %%
plt.errorbar(x,data2['CumulativeAverage'],yerr=data2['StatisticalUncertainty'])
plt.errorbar(x,data1['CumulativeAverage'],yerr=data1['StatisticalUncertainty'])
plt.xlabel('#throws')
plt.ylabel('<I>')
plt.grid(True)
plt.show()
